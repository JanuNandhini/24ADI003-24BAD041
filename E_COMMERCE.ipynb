# %% [markdown]
# <a href="https://colab.research.google.com/github/JanuNandhini/Janu-Nandhini-E-24BAD041/blob/main/E_COMMERCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"/content/data (1).csv", encoding="cp1252")

# %%
print(df.head())
print(df.info())
print(df.isnull().sum())
#Janu Nandhini E,24BAD041
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
# ...

# %%
df["Sales"] = df["Quantity"] * df["UnitPrice"]
sales = df.groupby("Description")["Sales"].sum().head(5)

sales.plot(kind="bar")
plt.show()
#Janu Nandhini E,24BAD041

# %%
sales.plot(kind="line")
plt.show()#Janu Nandhini E,24BAD041
